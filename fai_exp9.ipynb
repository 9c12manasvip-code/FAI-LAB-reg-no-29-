# %% [markdown]
# <a href="https://colab.research.google.com/github/9c12manasvip-code/FAI-LAB-reg-no-29-/blob/main/fai_exp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
EXPERIMENT 9

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Internal technical text + labels (1 = threat, 0 = safe)
texts = [
    "disabled authentication temporarily",
    "system running normally",
    "hardcoded api key added",
    "user logged in successfully"
]
labels = [1, 0, 1, 0]

# Convert text to features
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# Train supervised model
model = LogisticRegression()
model.fit(X, labels)

# New internal message
test_text = ["bypassed validation for quick fix"]
X_test = vectorizer.transform(test_text)

print("Threat Detected:", model.predict(X_test)[0])
# Out:
# Threat Detected: 1
